# %% [markdown]
# Credit to /u/tacoslim for the strategy

# %%
# Note: the data must be in the same directory as this notebook to function correctly
# Start by wrangling the data
import pandas as pd
btcdf = pd.read_csv('BTC-CoinDesk.csv', 
                    index_col = 'Date',
                    parse_dates=True, 
                   )
btcdf.head()
# Out:
#            Currency  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# Date
# 2013-10-01      BTC            123.65499       124.30466       124.75166
# 2013-10-02      BTC            125.45500       123.65499       125.75850
# 2013-10-03      BTC            108.58483       125.45500       125.66566
# 2013-10-04      BTC            118.67466       108.58483       118.67500
# 2013-10-05      BTC            121.33866       118.67466       121.93633
#
#             24h Low (USD)
# Date
# 2013-10-01      122.56349
# 2013-10-02      123.63383
# 2013-10-03       83.32833
# 2013-10-04      107.05816
# 2013-10-05      118.00566

# %%
btcdf = btcdf['24h Open (USD)']
btcdf
# Out:
# Date
# 2013-10-01      124.304660
# 2013-10-02      123.654990
# 2013-10-03      125.455000
# 2013-10-04      108.584830
# 2013-10-05      118.674660
#                   ...
# 2021-03-24    54143.106041
# 2021-03-25    54375.807629
# 2021-03-26    52335.565034
# 2021-03-27    51344.048980
# 2021-03-28    55067.824399
# Name: 24h Open (USD), Length: 2736, dtype: float64

# %%
ethdf = pd.read_csv('ETH-CoinDesk.csv',
                     index_col = 'Date',
                     parse_dates=True, 
                   )
ethdf.head()
# Out:
#            Currency  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# Date
# 2015-08-09      ETH             0.909046        1.749289        1.916540
# 2015-08-10      ETH             0.692321        0.909046        0.909046
# 2015-08-11      ETH             0.668067        0.692321        0.692321
# 2015-08-12      ETH             0.850151        0.668067        1.148621
# 2015-08-13      ETH             1.266023        0.850151        1.266023
#
#             24h Low (USD)
# Date
# 2015-08-09       0.794497
# 2015-08-10       0.692321
# 2015-08-11       0.654331
# 2015-08-12       0.668067
# 2015-08-13       0.850151

# %%
ethdf = ethdf['24h Open (USD)']
ethdf
# Out:
# Date
# 2015-08-09       1.749289
# 2015-08-10       0.909046
# 2015-08-11       0.692321
# 2015-08-12       0.668067
# 2015-08-13       0.850151
#                  ...
# 2021-03-24    1682.982718
# 2021-03-25    1669.164560
# 2021-03-26    1583.394738
# 2021-03-27    1587.234415
# 2021-03-28    1700.081390
# Name: 24h Open (USD), Length: 2059, dtype: float64

# %%
btcStartDate = btcdf.index[0]
print(btcStartDate)
ethStartDate = ethdf.index[0]
#startDate = max(btcStartDate, ethStartDate)
startDate = '2017-08-09 00:00:00'
print(startDate)
# Out:
# 2013-10-01 00:00:00
# 2017-08-09 00:00:00

# %%
btcdf = btcdf.where(btcdf.index >= startDate)
btcdf = btcdf.dropna()
btcdf
# Out:
# Date
# 2017-08-09     3474.762500
# 2017-08-10     3416.185000
# 2017-08-11     3364.411250
# 2017-08-12     3451.852500
# 2017-08-13     3705.430000
#                   ...
# 2021-03-24    54143.106041
# 2021-03-25    54375.807629
# 2021-03-26    52335.565034
# 2021-03-27    51344.048980
# 2021-03-28    55067.824399
# Name: 24h Open (USD), Length: 1328, dtype: float64

# %%
ethdf = ethdf.where(ethdf.index >= startDate)
ethdf = ethdf.dropna()
ethdf
# Out:
# Date
# 2017-08-09     272.195838
# 2017-08-10     315.197193
# 2017-08-11     292.309764
# 2017-08-12     301.244641
# 2017-08-13     312.508364
#                  ...
# 2021-03-24    1682.982718
# 2021-03-25    1669.164560
# 2021-03-26    1583.394738
# 2021-03-27    1587.234415
# 2021-03-28    1700.081390
# Name: 24h Open (USD), Length: 1328, dtype: float64

# %%
btcdf = btcdf.to_frame()
btcdf['Scaled'] = btcdf.divide(btcdf.iloc[0])
btcdf
# Out:
#             24h Open (USD)     Scaled
# Date
# 2017-08-09     3474.762500   1.000000
# 2017-08-10     3416.185000   0.983142
# 2017-08-11     3364.411250   0.968242
# 2017-08-12     3451.852500   0.993407
# 2017-08-13     3705.430000   1.066384
# ...                    ...        ...
# 2021-03-24    54143.106041  15.581815
# 2021-03-25    54375.807629  15.648784
# 2021-03-26    52335.565034  15.061624
# 2021-03-27    51344.048980  14.776276
# 2021-03-28    55067.824399  15.847939
#
# [1328 rows x 2 columns]

# %%
ethdf = ethdf.to_frame()
ethdf['Scaled'] = ethdf.divide(ethdf.iloc[0])
ethdf
# Out:
#             24h Open (USD)    Scaled
# Date
# 2017-08-09      272.195838  1.000000
# 2017-08-10      315.197193  1.157979
# 2017-08-11      292.309764  1.073895
# 2017-08-12      301.244641  1.106720
# 2017-08-13      312.508364  1.148101
# ...                    ...       ...
# 2021-03-24     1682.982718  6.182985
# 2021-03-25     1669.164560  6.132219
# 2021-03-26     1583.394738  5.817116
# 2021-03-27     1587.234415  5.831222
# 2021-03-28     1700.081390  6.245802
#
# [1328 rows x 2 columns]

# %%
# Visualise the data
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.title('Ethereum price over time')
plt.plot(ethdf['Scaled'])

# %%
plt.figure(figsize=(12,5))
plt.title('Bitcoin price over time')
plt.plot(btcdf['Scaled'])

# %%
plt.figure(figsize=(12,5))
plt.title('Both signals')
plt.plot(btcdf['Scaled'], label="btc")
plt.plot(ethdf['Scaled'], label="eth")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# These price series look similar. To quantify this we perform cointegration tests on the returns of each cryptocurrency.

# %%
btcdf['Returns'] = btcdf['24h Open (USD)'].pct_change()

# %%
btcdf = btcdf.dropna()
btcdf
# Out:
#             24h Open (USD)     Scaled   Returns
# Date
# 2017-08-10     3416.185000   0.983142 -0.016858
# 2017-08-11     3364.411250   0.968242 -0.015155
# 2017-08-12     3451.852500   0.993407  0.025990
# 2017-08-13     3705.430000   1.066384  0.073461
# 2017-08-14     4104.015000   1.181092  0.107568
# ...                    ...        ...       ...
# 2021-03-24    54143.106041  15.581815 -0.056563
# 2021-03-25    54375.807629  15.648784  0.004298
# 2021-03-26    52335.565034  15.061624 -0.037521
# 2021-03-27    51344.048980  14.776276 -0.018945
# 2021-03-28    55067.824399  15.847939  0.072526
#
# [1327 rows x 3 columns]

# %%
ethdf['Returns'] = ethdf['24h Open (USD)'].pct_change()

# %%
ethdf = ethdf.dropna()
ethdf
# Out:
#             24h Open (USD)    Scaled   Returns
# Date
# 2017-08-10      315.197193  1.157979  0.157979
# 2017-08-11      292.309764  1.073895 -0.072613
# 2017-08-12      301.244641  1.106720  0.030566
# 2017-08-13      312.508364  1.148101  0.037391
# 2017-08-14      299.769888  1.101302 -0.040762
# ...                    ...       ...       ...
# 2021-03-24     1682.982718  6.182985 -0.056687
# 2021-03-25     1669.164560  6.132219 -0.008211
# 2021-03-26     1583.394738  5.817116 -0.051385
# 2021-03-27     1587.234415  5.831222  0.002425
# 2021-03-28     1700.081390  6.245802  0.071097
#
# [1327 rows x 3 columns]

# %%
plt.scatter(ethdf['Returns'].shift(0), btcdf['Returns'])
plt.title('Relation between eth and btc returns')
plt.show()

# %%
# Test for cointegration between the two series. The null hypothesis is that there is no cointegration between 
# ethereum and bitcoin.
# If the P value is below 5%, we can reject the null hypothesis
import statsmodels.tsa.stattools as ts
cointegration, p_value, crit = ts.coint(btcdf['Returns'], ethdf['Returns'])
print("P value is: " + str(p_value))
# Out:
# P value is: 7.272579300468183e-08

# %% [markdown]
# From the p value calculated, we can reject the hypothesis that there is no cointegration.

# %%
import statistics as stat
# Calculate the ratio between prices
plt.figure(figsize=(12,5))
plt.title('Ratio between btc/eth price changes')
plt.hlines(stat.mean(btcdf['Scaled']/ethdf['Scaled']), 
           ethdf.index[0], 
           ethdf.index[-1], 
           color="red", 
           label="mean")
plt.plot(btcdf['Scaled']/ethdf['Scaled'], 
         label="btc/eth")

plt.legend(loc="upper left")
plt.show()

# %%
# This isn't useful without normalizing the data. 
# We compute the z-score using a window of the previous 30 days to avoid look-ahead bias
from scipy import stats

z_scores = [stats.zscore( (btcdf['Scaled']/ethdf['Scaled'])[i-30:i])[0] for i in range(30, btcdf.shape[0])]
len(z_scores)
# Out:
# 1168

# %%
# Visualise the normalized ratio between prices
plt.figure(figsize=(12,5))
plt.title('Normalized ratio between btc/eth price changes')
plt.plot(z_scores)
plt.show()

# %% [markdown]
# Now to generate to buy/ sell signals. When the ratio goes above +2 btc is overvalued relative to eth, so we short btc and long eth; the opposite is done at -2, as we expect the ratio to revert.

# %%
# Visualise the buy/sell signals
plt.figure(figsize=(12,5))
plt.title('Normalized ratio between btc/eth price changes with signals')
plt.hlines(2, 
           0, 
           len(z_scores), 
           color="red", 
           label="short btc")

plt.hlines(-2, 
           0, 
           len(z_scores), 
           color="green", 
           label="long btc")
plt.plot(z_scores, label= "normalized ratio")

plt.legend(loc="upper left")
plt.show()

# %%
status = 0 # initalize at 0, set to -1 when going long and +1 when going short on btc

signals = []
for i in range(0, len(z_scores)):
    if np.less(z_scores[i], -2):
        status = -2
    elif np.greater(z_scores[i], 2):
        status = 2
    signals.append(status)

# %%
plt.figure(figsize=(12,5))
plt.plot(z_scores, label= "normalized ratio")
plt.plot(signals)

# %% [markdown]
# # Discussion:
# blah
